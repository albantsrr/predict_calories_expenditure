# %% [markdown]
# # NEURAL NETWORK TRAINING

# %% [markdown]
# ## REFERENCE
# https://www.kaggle.com/code/cdeotte/nn-mlp-starter-cv-0-0608

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Embedding
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.layers import Activation
import tensorflow.keras.backend as K

VER = 1
# Out:
# 2025-05-26 16:08:30.096674: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-26 16:08:30.151679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748268510.188443  195022 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748268510.198950  195022 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748268510.244727  195022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748268510.244774  195022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748268510.244775  195022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748268510.244777  195022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-26 16:08:30.258539: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = pd.read_csv('../data/X.csv')
y = pd.read_csv('../data/y.csv')
X_test = pd.read_csv('../data/X_test.csv')

FEATURES = X.columns.tolist()
TARGET = 'Calories'

# %%
# SIMPLE MLP
def build_model(size=len(FEATURES)):
    x_in = Input(shape=(size,))
    x = Dense(32)(x_in)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(32)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    x = Dense(1, activation='linear')(x)
    model = Model(inputs=x_in, outputs=x)
    return model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

def make_callbacks(): 
    lr_callback = ReduceLROnPlateau(
        monitor='val_loss',
        factor = 0.5,
        patience = 3,
        verbose= 1,
        min_lr=1e-6
    )
    early_stop_cb = EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        mode="min",
        verbose=1
    )
    return [lr_callback, early_stop_cb]

EPOCHS = 100

# %%
y.head()
# Out:
#    Calories
# 0  5.017280
# 1  3.555348
# 2  3.401197
# 3  4.948760
# 4  4.990433

# %%
import time
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

FOLDS = 5
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Arrays pour stocker les prédictions en échelle ORIGINALE
test_predictions = np.zeros(len(X_test))
oof_predictions = np.zeros(len(X))

for fold, (train_idx, valid_idx) in enumerate(kf.split(X, y)):
    
    print(f"\n{'#'*28}")
    print(f"{'#'*10} Fold {fold+1} {'#'*10}")
    print(f"{'#'*28}")
    
    # TRAIN
    X_train = X.loc[train_idx, FEATURES].copy()
    y_train = np.log1p(y.loc[train_idx, TARGET])
    
    # EXTRA DATA
    # for k in range(4):
    #     X_train = pd.concat([X_train,orig[FEATURES]],axis=0)
    #     y_train = pd.concat([y_train,np.log1p( orig[TARGET] )],axis=0)
    
    # VALID
    X_valid = X.loc[valid_idx, FEATURES].copy()
    y_valid_log = np.log1p(y.loc[valid_idx, TARGET])        # Pour l'entraînement
    y_valid_original = y.loc[valid_idx, TARGET]             # Pour le calcul RMSE
    
    # TEST
    X_test_data = X_test[FEATURES].copy()
    
    # NORMALIZE FOR NN
    print("Normalizing...", end='')
    # Spécifier explicitement les colonnes numériques
    norm_cols = [c for c in FEATURES if X_train[c].dtype in ['float64', 'int64', 'float32', 'int32']]
    
    means = X_train[norm_cols].mean()
    stds = X_train[norm_cols].std()
    stds = stds.replace(0, 1)
    X_train[norm_cols] = (X_train[norm_cols] - means) / stds
    X_valid[norm_cols] = (X_valid[norm_cols] - means) / stds
    X_test_data[norm_cols] = (X_test_data[norm_cols] - means) / stds
    print("done")
    
    start = time.time()
    
    K.clear_session()
    model = build_model(X_train.shape[1])
    model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
                  loss="mse",
                  metrics=[tf.keras.metrics.RootMeanSquaredError()],
                  )
    model.fit(X_train, y_train,
              validation_data=(X_valid, y_valid_log),  # Utiliser version log pour validation
              callbacks=make_callbacks(),
              batch_size=256, epochs=EPOCHS, verbose=2)
    
    # Prédictions en échelle LOG
    oof_pred_log = model.predict(X_valid, batch_size=512, verbose=2).flatten()
    test_pred_log = model.predict(X_test_data, batch_size=512, verbose=2).flatten()
    
    # RETRANSFORMATION en échelle originale avant stockage
    oof_pred_original = np.expm1(oof_pred_log)
    test_pred_original = np.expm1(test_pred_log)
    
    # Stockage des prédictions en échelle originale
    oof_predictions[valid_idx] = oof_pred_original
    test_predictions += test_pred_original
    
    # RMSE calculé en échelle originale (plus interprétable)
    rmse = np.sqrt(mean_squared_error(y_valid_original, oof_pred_original))
    print(f"Fold {fold+1} RMSE: {rmse:.4f}")
    print(f"Feature engineering & training time: {time.time() - start:.1f} sec")

# Moyenne des prédictions test (en échelle originale)
test_predictions /= FOLDS

# Calcul du RMSE global OOF
overall_rmse = np.sqrt(mean_squared_error(y[TARGET], oof_predictions))
print(f"\nOverall OOF RMSE: {overall_rmse:.4f}")

# Vérifications de cohérence
print(f"\nPredictions Summary:")
print(f"OOF range: {oof_predictions.min():.2f} - {oof_predictions.max():.2f}")
print(f"Test range: {test_predictions.min():.2f} - {test_predictions.max():.2f}")
print(f"Target range: {y[TARGET].min():.2f} - {y[TARGET].max():.2f}")
# Out:
# ############################
# ########## Fold 1 ##########
# ############################
# Normalizing...done
# I0000 00:00:1748268519.173369  195022 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5566 MB memory:  -> device: 0, name: NVIDIA RTX 2000 Ada Generation Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748268521.328622  195191 service.cc:152] XLA service 0x7f63400101d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748268521.328699  195191 service.cc:160]   StreamExecutor device (0): NVIDIA RTX 2000 Ada Generation Laptop GPU, Compute Capability 8.9
# 2025-05-26 16:08:41.365796: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1748268521.585718  195191 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1748268522.222029  195191 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2344/2344 - 12s - 5ms/step - loss: 0.0356 - root_mean_squared_error: 0.1887 - val_loss: 8.6489e-04 - val_root_mean_squared_error: 0.0294 - learning_rate: 1.0000e-03
# Epoch 2/100
# 2344/2344 - 14s - 6ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 8.9699e-04 - val_root_mean_squared_error: 0.0299 - learning_rate: 1.0000e-03
# Epoch 3/100
# 2344/2344 - 14s - 6ms/step - loss: 0.0011 - root_mean_squared_error: 0.0336 - val_loss: 5.9441e-04 - val_root_mean_squared_error: 0.0244 - learning_rate: 1.0000e-03
# Epoch 4/100
# 2344/2344 - 14s - 6ms/step - loss: 9.9634e-04 - root_mean_squared_error: 0.0316 - val_loss: 5.5774e-04 - val_root_mean_squared_error: 0.0236 - learning_rate: 1.0000e-03
# Epoch 5/100
# 2344/2344 - 14s - 6ms/step - loss: 8.8912e-04 - root_mean_squared_error: 0.0298 - val_loss: 4.8979e-04 - val_root_mean_squared_error: 0.0221 - learning_rate: 1.0000e-03
# Epoch 6/100
# 2344/2344 - 14s - 6ms/step - loss: 8.1714e-04 - root_mean_squared_error: 0.0286 - val_loss: 9.0093e-04 - val_root_mean_squared_error: 0.0300 - learning_rate: 1.0000e-03
# Epoch 7/100
# 2344/2344 - 14s - 6ms/step - loss: 7.5775e-04 - root_mean_squared_error: 0.0275 - val_loss: 5.5135e-04 - val_root_mean_squared_error: 0.0235 - learning_rate: 1.0000e-03
# Epoch 8/100
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2344/2344 - 14s - 6ms/step - loss: 7.0125e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.0471e-04 - val_root_mean_squared_error: 0.0201 - learning_rate: 1.0000e-03
# Epoch 9/100
# 2344/2344 - 14s - 6ms/step - loss: 6.0280e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.1223e-04 - val_root_mean_squared_error: 0.0203 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2344/2344 - 14s - 6ms/step - loss: 5.8997e-04 - root_mean_squared_error: 0.0243 - val_loss: 3.8774e-04 - val_root_mean_squared_error: 0.0197 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2344/2344 - 14s - 6ms/step - loss: 5.8502e-04 - root_mean_squared_error: 0.0242 - val_loss: 3.6263e-04 - val_root_mean_squared_error: 0.0190 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2344/2344 - 14s - 6ms/step - loss: 5.6098e-04 - root_mean_squared_error: 0.0237 - val_loss: 4.2936e-04 - val_root_mean_squared_error: 0.0207 - learning_rate: 5.0000e-04
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2344/2344 - 14s - 6ms/step - loss: 5.5426e-04 - root_mean_squared_error: 0.0235 - val_loss: 4.3434e-04 - val_root_mean_squared_error: 0.0208 - learning_rate: 5.0000e-04
# Epoch 14/100
# 2344/2344 - 14s - 6ms/step - loss: 5.0256e-04 - root_mean_squared_error: 0.0224 - val_loss: 4.2648e-04 - val_root_mean_squared_error: 0.0207 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2344/2344 - 14s - 6ms/step - loss: 5.0252e-04 - root_mean_squared_error: 0.0224 - val_loss: 3.6291e-04 - val_root_mean_squared_error: 0.0191 - learning_rate: 2.5000e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2344/2344 - 14s - 6ms/step - loss: 5.0588e-04 - root_mean_squared_error: 0.0225 - val_loss: 3.5794e-04 - val_root_mean_squared_error: 0.0189 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2344/2344 - 14s - 6ms/step - loss: 4.6980e-04 - root_mean_squared_error: 0.0217 - val_loss: 3.7001e-04 - val_root_mean_squared_error: 0.0192 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2344/2344 - 14s - 6ms/step - loss: 4.6778e-04 - root_mean_squared_error: 0.0216 - val_loss: 3.4183e-04 - val_root_mean_squared_error: 0.0185 - learning_rate: 1.2500e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2344/2344 - 14s - 6ms/step - loss: 4.6276e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.4936e-04 - val_root_mean_squared_error: 0.0187 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2344/2344 - 14s - 6ms/step - loss: 4.5424e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.2553e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2344/2344 - 15s - 6ms/step - loss: 4.4647e-04 - root_mean_squared_error: 0.0211 - val_loss: 3.2537e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 6.2500e-05
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2344/2344 - 14s - 6ms/step - loss: 4.4389e-04 - root_mean_squared_error: 0.0211 - val_loss: 3.3692e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 6.2500e-05
# Epoch 23/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3774e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.2611e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3756e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.2146e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 3.1250e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2344/2344 - 13s - 6ms/step - loss: 4.3868e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.2053e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 3.1250e-05
# Epoch 26/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3138e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1931e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.5625e-05
# Epoch 27/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3614e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1996e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.5625e-05
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2344/2344 - 14s - 6ms/step - loss: 4.4002e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.2049e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.5625e-05
# Epoch 29/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3512e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1918e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 7.8125e-06
# Epoch 30/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3108e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1866e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 7.8125e-06
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2344/2344 - 13s - 6ms/step - loss: 4.3815e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1869e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 7.8125e-06
# Epoch 32/100
# 2344/2344 - 14s - 6ms/step - loss: 4.2894e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1858e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 3.9063e-06
# Epoch 33/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3181e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1876e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 3.9063e-06
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2344/2344 - 14s - 6ms/step - loss: 4.3593e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1856e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 3.9063e-06
# Epoch 35/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3022e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1827e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.9531e-06
# Epoch 36/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3118e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1910e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.9531e-06
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2344/2344 - 14s - 6ms/step - loss: 4.3246e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1895e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.9531e-06
# Epoch 38/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3525e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1997e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3322e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1830e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3448e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1834e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3167e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1993e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2344/2344 - 15s - 6ms/step - loss: 4.2906e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1946e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3160e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1982e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3210e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1994e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3626e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1780e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3138e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1883e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3312e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1816e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 48/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3027e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1892e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 49/100
# 2344/2344 - 14s - 6ms/step - loss: 4.2988e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1823e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 50/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3206e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1834e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 51/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3010e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1780e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 52/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3556e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1845e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 53/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3159e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1829e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 54/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3348e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1849e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 55/100
# 2344/2344 - 13s - 6ms/step - loss: 4.2860e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1814e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 56/100
# 2344/2344 - 14s - 6ms/step - loss: 4.2863e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1809e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 57/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3030e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1910e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 58/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3500e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1966e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 59/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3028e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1822e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 60/100
# 2344/2344 - 13s - 6ms/step - loss: 4.3685e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1877e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 61/100
# 2344/2344 - 13s - 6ms/step - loss: 4.2877e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1835e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 51.
# 293/293 - 1s - 3ms/step
# 489/489 - 1s - 2ms/step
# Fold 1 RMSE: 0.0616
# Feature engineering & training time: 841.6 sec
#
# ############################
# ########## Fold 2 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2344/2344 - 16s - 7ms/step - loss: 0.1080 - root_mean_squared_error: 0.3287 - val_loss: 7.0778e-04 - val_root_mean_squared_error: 0.0266 - learning_rate: 1.0000e-03
# Epoch 2/100
# 2344/2344 - 13s - 6ms/step - loss: 0.0014 - root_mean_squared_error: 0.0371 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352 - learning_rate: 1.0000e-03
# Epoch 3/100
# 2344/2344 - 13s - 6ms/step - loss: 0.0011 - root_mean_squared_error: 0.0335 - val_loss: 6.5829e-04 - val_root_mean_squared_error: 0.0257 - learning_rate: 1.0000e-03
# Epoch 4/100
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2344/2344 - 13s - 6ms/step - loss: 9.6113e-04 - root_mean_squared_error: 0.0310 - val_loss: 7.8300e-04 - val_root_mean_squared_error: 0.0280 - learning_rate: 1.0000e-03
# Epoch 5/100
# 2344/2344 - 14s - 6ms/step - loss: 7.7076e-04 - root_mean_squared_error: 0.0278 - val_loss: 4.7087e-04 - val_root_mean_squared_error: 0.0217 - learning_rate: 5.0000e-04
# Epoch 6/100
# 2344/2344 - 14s - 6ms/step - loss: 7.0954e-04 - root_mean_squared_error: 0.0266 - val_loss: 5.4383e-04 - val_root_mean_squared_error: 0.0233 - learning_rate: 5.0000e-04
# Epoch 7/100
# 2344/2344 - 15s - 6ms/step - loss: 6.9681e-04 - root_mean_squared_error: 0.0264 - val_loss: 5.6646e-04 - val_root_mean_squared_error: 0.0238 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2344/2344 - 14s - 6ms/step - loss: 6.5738e-04 - root_mean_squared_error: 0.0256 - val_loss: 3.6837e-04 - val_root_mean_squared_error: 0.0192 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2344/2344 - 14s - 6ms/step - loss: 6.2758e-04 - root_mean_squared_error: 0.0251 - val_loss: 4.2531e-04 - val_root_mean_squared_error: 0.0206 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2344/2344 - 14s - 6ms/step - loss: 6.0334e-04 - root_mean_squared_error: 0.0246 - val_loss: 4.4401e-04 - val_root_mean_squared_error: 0.0211 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2344/2344 - 14s - 6ms/step - loss: 5.8920e-04 - root_mean_squared_error: 0.0243 - val_loss: 3.8402e-04 - val_root_mean_squared_error: 0.0196 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2344/2344 - 14s - 6ms/step - loss: 5.2544e-04 - root_mean_squared_error: 0.0229 - val_loss: 3.8422e-04 - val_root_mean_squared_error: 0.0196 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2344/2344 - 14s - 6ms/step - loss: 5.1939e-04 - root_mean_squared_error: 0.0228 - val_loss: 4.3496e-04 - val_root_mean_squared_error: 0.0209 - learning_rate: 2.5000e-04
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2344/2344 - 14s - 6ms/step - loss: 5.1688e-04 - root_mean_squared_error: 0.0227 - val_loss: 3.6946e-04 - val_root_mean_squared_error: 0.0192 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2344/2344 - 14s - 6ms/step - loss: 4.7011e-04 - root_mean_squared_error: 0.0217 - val_loss: 3.4137e-04 - val_root_mean_squared_error: 0.0185 - learning_rate: 1.2500e-04
# Epoch 16/100
# 2344/2344 - 14s - 6ms/step - loss: 4.7449e-04 - root_mean_squared_error: 0.0218 - val_loss: 3.4766e-04 - val_root_mean_squared_error: 0.0186 - learning_rate: 1.2500e-04
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2344/2344 - 14s - 6ms/step - loss: 4.6680e-04 - root_mean_squared_error: 0.0216 - val_loss: 3.5175e-04 - val_root_mean_squared_error: 0.0188 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2344/2344 - 15s - 6ms/step - loss: 4.5270e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.3772e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 6.2500e-05
# Epoch 19/100
# 2344/2344 - 14s - 6ms/step - loss: 4.4575e-04 - root_mean_squared_error: 0.0211 - val_loss: 3.3442e-04 - val_root_mean_squared_error: 0.0183 - learning_rate: 6.2500e-05
# Epoch 20/100
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2344/2344 - 14s - 6ms/step - loss: 4.4225e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.3398e-04 - val_root_mean_squared_error: 0.0183 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3971e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.4147e-04 - val_root_mean_squared_error: 0.0185 - learning_rate: 3.1250e-05
# Epoch 22/100
# 2344/2344 - 14s - 6ms/step - loss: 4.4024e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.2750e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.1250e-05
# Epoch 23/100
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2344/2344 - 14s - 6ms/step - loss: 4.3058e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.2798e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3060e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.2813e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.5625e-05
# Epoch 25/100
# 2344/2344 - 14s - 6ms/step - loss: 4.3184e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.2917e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.5625e-05
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2344/2344 - 13s - 6ms/step - loss: 4.3148e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.3120e-04 - val_root_mean_squared_error: 0.0182 - learning_rate: 1.5625e-05
# Epoch 27/100
# 2344/2344 - 14s - 6ms/step - loss: 4.2780e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.2819e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 7.8125e-06
# Epoch 28/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2814e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.2794e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 7.8125e-06
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2344/2344 - 15s - 6ms/step - loss: 4.2679e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.2672e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 7.8125e-06
# Epoch 30/100
# 2344/2344 - 15s - 6ms/step - loss: 4.2577e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2721e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.9063e-06
# Epoch 31/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2548e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2607e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.9063e-06
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2344/2344 - 16s - 7ms/step - loss: 4.2725e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.2771e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 3.9063e-06
# Epoch 33/100
# 2344/2344 - 15s - 6ms/step - loss: 4.2407e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2723e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.9531e-06
# Epoch 34/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2800e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.2732e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.9531e-06
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2344/2344 - 15s - 6ms/step - loss: 4.2474e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2636e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.9531e-06
# Epoch 36/100
# 2344/2344 - 12s - 5ms/step - loss: 4.2336e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2633e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 37/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2465e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2676e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 38/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2219e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2662e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2210e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2598e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2439e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2605e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2086e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2639e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2352e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2642e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2549e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2605e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2401e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2625e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2214e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2607e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2379e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2597e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2171e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2610e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 48/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2174e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2756e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 49/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2304e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2737e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 50/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2182e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2713e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 51/100
# 2344/2344 - 15s - 7ms/step - loss: 4.2232e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2564e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 52/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2081e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2630e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 53/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2084e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2663e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 54/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2150e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2583e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 55/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2283e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2716e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 56/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2038e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2638e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 57/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2641e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2601e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 58/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2337e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2596e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 59/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2152e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.2606e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 60/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2271e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2608e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 61/100
# 2344/2344 - 19s - 8ms/step - loss: 4.2234e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2607e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.0000e-06
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 51.
# 293/293 - 1s - 4ms/step
# 489/489 - 1s - 3ms/step
# Fold 2 RMSE: 0.0636
# Feature engineering & training time: 925.1 sec
#
# ############################
# ########## Fold 3 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2344/2344 - 21s - 9ms/step - loss: 0.0540 - root_mean_squared_error: 0.2324 - val_loss: 7.9825e-04 - val_root_mean_squared_error: 0.0283 - learning_rate: 1.0000e-03
# Epoch 2/100
# 2344/2344 - 18s - 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0388 - val_loss: 6.4945e-04 - val_root_mean_squared_error: 0.0255 - learning_rate: 1.0000e-03
# Epoch 3/100
# 2344/2344 - 20s - 8ms/step - loss: 0.0012 - root_mean_squared_error: 0.0339 - val_loss: 5.1290e-04 - val_root_mean_squared_error: 0.0226 - learning_rate: 1.0000e-03
# Epoch 4/100
# 2344/2344 - 17s - 7ms/step - loss: 0.0010 - root_mean_squared_error: 0.0322 - val_loss: 8.8886e-04 - val_root_mean_squared_error: 0.0298 - learning_rate: 1.0000e-03
# Epoch 5/100
# 2344/2344 - 17s - 7ms/step - loss: 9.2185e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9072e-04 - val_root_mean_squared_error: 0.0222 - learning_rate: 1.0000e-03
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2344/2344 - 18s - 8ms/step - loss: 8.2353e-04 - root_mean_squared_error: 0.0287 - val_loss: 7.2662e-04 - val_root_mean_squared_error: 0.0270 - learning_rate: 1.0000e-03
# Epoch 7/100
# 2344/2344 - 18s - 8ms/step - loss: 6.7657e-04 - root_mean_squared_error: 0.0260 - val_loss: 3.9003e-04 - val_root_mean_squared_error: 0.0197 - learning_rate: 5.0000e-04
# Epoch 8/100
# 2344/2344 - 18s - 8ms/step - loss: 6.4607e-04 - root_mean_squared_error: 0.0254 - val_loss: 3.6951e-04 - val_root_mean_squared_error: 0.0192 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2344/2344 - 16s - 7ms/step - loss: 6.3267e-04 - root_mean_squared_error: 0.0252 - val_loss: 3.5712e-04 - val_root_mean_squared_error: 0.0189 - learning_rate: 5.0000e-04
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2344/2344 - 16s - 7ms/step - loss: 6.2671e-04 - root_mean_squared_error: 0.0250 - val_loss: 3.6128e-04 - val_root_mean_squared_error: 0.0190 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2344/2344 - 15s - 7ms/step - loss: 5.6157e-04 - root_mean_squared_error: 0.0237 - val_loss: 3.3673e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 2.5000e-04
# Epoch 12/100
# 2344/2344 - 17s - 7ms/step - loss: 5.4750e-04 - root_mean_squared_error: 0.0234 - val_loss: 3.8640e-04 - val_root_mean_squared_error: 0.0197 - learning_rate: 2.5000e-04
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2344/2344 - 17s - 7ms/step - loss: 5.3697e-04 - root_mean_squared_error: 0.0232 - val_loss: 3.8328e-04 - val_root_mean_squared_error: 0.0196 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2344/2344 - 18s - 8ms/step - loss: 5.1350e-04 - root_mean_squared_error: 0.0227 - val_loss: 3.3717e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 1.2500e-04
# Epoch 15/100
# 2344/2344 - 17s - 7ms/step - loss: 5.0369e-04 - root_mean_squared_error: 0.0224 - val_loss: 3.5423e-04 - val_root_mean_squared_error: 0.0188 - learning_rate: 1.2500e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.9970e-04 - root_mean_squared_error: 0.0224 - val_loss: 3.2847e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.2500e-04
# Epoch 17/100
# 2344/2344 - 18s - 8ms/step - loss: 4.7933e-04 - root_mean_squared_error: 0.0219 - val_loss: 3.3456e-04 - val_root_mean_squared_error: 0.0183 - learning_rate: 6.2500e-05
# Epoch 18/100
# 2344/2344 - 17s - 7ms/step - loss: 4.8083e-04 - root_mean_squared_error: 0.0219 - val_loss: 3.3353e-04 - val_root_mean_squared_error: 0.0183 - learning_rate: 6.2500e-05
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.7341e-04 - root_mean_squared_error: 0.0218 - val_loss: 3.4848e-04 - val_root_mean_squared_error: 0.0187 - learning_rate: 6.2500e-05
# Epoch 20/100
# 2344/2344 - 17s - 7ms/step - loss: 4.7377e-04 - root_mean_squared_error: 0.0218 - val_loss: 3.2503e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.1250e-05
# Epoch 21/100
# 2344/2344 - 17s - 7ms/step - loss: 4.7155e-04 - root_mean_squared_error: 0.0217 - val_loss: 3.2485e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.1250e-05
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2344/2344 - 16s - 7ms/step - loss: 4.6940e-04 - root_mean_squared_error: 0.0217 - val_loss: 3.2564e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.1250e-05
# Epoch 23/100
# 2344/2344 - 18s - 8ms/step - loss: 4.6200e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.3126e-04 - val_root_mean_squared_error: 0.0182 - learning_rate: 1.5625e-05
# Epoch 24/100
# 2344/2344 - 17s - 7ms/step - loss: 4.6127e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.2814e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.5625e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.6099e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.2695e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 1.5625e-05
# Epoch 26/100
# 2344/2344 - 18s - 8ms/step - loss: 4.5999e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2331e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 7.8125e-06
# Epoch 27/100
# 2344/2344 - 16s - 7ms/step - loss: 4.6130e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.2292e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 7.8125e-06
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.5641e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2390e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 7.8125e-06
# Epoch 29/100
# 2344/2344 - 16s - 7ms/step - loss: 4.6025e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.2237e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.9063e-06
# Epoch 30/100
# 2344/2344 - 15s - 7ms/step - loss: 4.5792e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2340e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.9063e-06
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2344/2344 - 15s - 7ms/step - loss: 4.5711e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2240e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.9063e-06
# Epoch 32/100
# 2344/2344 - 16s - 7ms/step - loss: 4.5633e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2291e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.9531e-06
# Epoch 33/100
# 2344/2344 - 15s - 7ms/step - loss: 4.5582e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.2314e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.9531e-06
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2344/2344 - 16s - 7ms/step - loss: 4.5404e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.2332e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.9531e-06
# Epoch 35/100
# 2344/2344 - 15s - 7ms/step - loss: 4.5102e-04 - root_mean_squared_error: 0.0212 - val_loss: 3.2269e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 36/100
# 2344/2344 - 16s - 7ms/step - loss: 4.5159e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.2274e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 37/100
# 2344/2344 - 17s - 7ms/step - loss: 4.5585e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.2305e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 38/100
# 2344/2344 - 18s - 8ms/step - loss: 4.5119e-04 - root_mean_squared_error: 0.0212 - val_loss: 3.2278e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2344/2344 - 18s - 8ms/step - loss: 4.5219e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.2275e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.0000e-06
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 293/293 - 1s - 4ms/step
# 489/489 - 1s - 3ms/step
# Fold 3 RMSE: 0.0629
# Feature engineering & training time: 668.0 sec
#
# ############################
# ########## Fold 4 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2344/2344 - 22s - 9ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 9.2730e-04 - val_root_mean_squared_error: 0.0305 - learning_rate: 1.0000e-03
# Epoch 2/100
# 2344/2344 - 17s - 7ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 8.5992e-04 - val_root_mean_squared_error: 0.0293 - learning_rate: 1.0000e-03
# Epoch 3/100
# 2344/2344 - 17s - 7ms/step - loss: 0.0011 - root_mean_squared_error: 0.0331 - val_loss: 9.4467e-04 - val_root_mean_squared_error: 0.0307 - learning_rate: 1.0000e-03
# Epoch 4/100
# 2344/2344 - 18s - 8ms/step - loss: 9.6896e-04 - root_mean_squared_error: 0.0311 - val_loss: 4.8719e-04 - val_root_mean_squared_error: 0.0221 - learning_rate: 1.0000e-03
# Epoch 5/100
# 2344/2344 - 17s - 7ms/step - loss: 8.8127e-04 - root_mean_squared_error: 0.0297 - val_loss: 4.2372e-04 - val_root_mean_squared_error: 0.0206 - learning_rate: 1.0000e-03
# Epoch 6/100
# 2344/2344 - 17s - 7ms/step - loss: 7.7653e-04 - root_mean_squared_error: 0.0279 - val_loss: 5.2784e-04 - val_root_mean_squared_error: 0.0230 - learning_rate: 1.0000e-03
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2344/2344 - 17s - 7ms/step - loss: 7.3801e-04 - root_mean_squared_error: 0.0272 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337 - learning_rate: 1.0000e-03
# Epoch 8/100
# 2344/2344 - 17s - 7ms/step - loss: 6.1261e-04 - root_mean_squared_error: 0.0248 - val_loss: 3.5482e-04 - val_root_mean_squared_error: 0.0188 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2344/2344 - 17s - 7ms/step - loss: 5.9958e-04 - root_mean_squared_error: 0.0245 - val_loss: 3.8379e-04 - val_root_mean_squared_error: 0.0196 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2344/2344 - 17s - 7ms/step - loss: 5.8748e-04 - root_mean_squared_error: 0.0242 - val_loss: 5.4472e-04 - val_root_mean_squared_error: 0.0233 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2344/2344 - 18s - 8ms/step - loss: 5.6315e-04 - root_mean_squared_error: 0.0237 - val_loss: 3.9187e-04 - val_root_mean_squared_error: 0.0198 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2344/2344 - 17s - 7ms/step - loss: 5.1166e-04 - root_mean_squared_error: 0.0226 - val_loss: 3.9334e-04 - val_root_mean_squared_error: 0.0198 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2344/2344 - 17s - 7ms/step - loss: 4.9686e-04 - root_mean_squared_error: 0.0223 - val_loss: 3.3733e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 2.5000e-04
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2344/2344 - 17s - 7ms/step - loss: 4.9279e-04 - root_mean_squared_error: 0.0222 - val_loss: 3.6640e-04 - val_root_mean_squared_error: 0.0191 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2344/2344 - 16s - 7ms/step - loss: 4.5845e-04 - root_mean_squared_error: 0.0214 - val_loss: 3.5395e-04 - val_root_mean_squared_error: 0.0188 - learning_rate: 1.2500e-04
# Epoch 16/100
# 2344/2344 - 15s - 7ms/step - loss: 4.5225e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.3759e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 1.2500e-04
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.4244e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.6152e-04 - val_root_mean_squared_error: 0.0190 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2344/2344 - 17s - 7ms/step - loss: 4.3531e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.3291e-04 - val_root_mean_squared_error: 0.0182 - learning_rate: 6.2500e-05
# Epoch 19/100
# 2344/2344 - 17s - 7ms/step - loss: 4.3295e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.2722e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 6.2500e-05
# Epoch 20/100
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.3596e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.2680e-04 - val_root_mean_squared_error: 0.0181 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1816e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.3230e-04 - val_root_mean_squared_error: 0.0182 - learning_rate: 3.1250e-05
# Epoch 22/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1779e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.2114e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 3.1250e-05
# Epoch 23/100
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.2271e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.2488e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2344/2344 - 18s - 7ms/step - loss: 4.1621e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.2008e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.5625e-05
# Epoch 25/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1609e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.1845e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.5625e-05
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.1568e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.2393e-04 - val_root_mean_squared_error: 0.0180 - learning_rate: 1.5625e-05
# Epoch 27/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1362e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1765e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 7.8125e-06
# Epoch 28/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1293e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1801e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 7.8125e-06
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2344/2344 - 18s - 8ms/step - loss: 4.1138e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1933e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 7.8125e-06
# Epoch 30/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1036e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1666e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 3.9063e-06
# Epoch 31/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1376e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1896e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 3.9063e-06
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.1405e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1829e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 3.9063e-06
# Epoch 33/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1500e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.1670e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.9531e-06
# Epoch 34/100
# 2344/2344 - 18s - 7ms/step - loss: 4.1097e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1830e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.9531e-06
# Epoch 35/100
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.0956e-04 - root_mean_squared_error: 0.0202 - val_loss: 3.1691e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.9531e-06
# Epoch 36/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1154e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1731e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 37/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1270e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1643e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 38/100
# 2344/2344 - 17s - 7ms/step - loss: 4.0801e-04 - root_mean_squared_error: 0.0202 - val_loss: 3.1689e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1091e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1731e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1124e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1778e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1303e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1619e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1422e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.1660e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2344/2344 - 19s - 8ms/step - loss: 4.1063e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1791e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1008e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1729e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1135e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1970e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1251e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1778e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2344/2344 - 16s - 7ms/step - loss: 4.1231e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1707e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 48/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1212e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1632e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 49/100
# 2344/2344 - 14s - 6ms/step - loss: 4.1214e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1794e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 50/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1186e-04 - root_mean_squared_error: 0.0203 - val_loss: 3.1735e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 51/100
# 2344/2344 - 17s - 7ms/step - loss: 4.0903e-04 - root_mean_squared_error: 0.0202 - val_loss: 3.1640e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 1.0000e-06
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 41.
# 293/293 - 1s - 4ms/step
# 489/489 - 1s - 2ms/step
# Fold 4 RMSE: 0.0623
# Feature engineering & training time: 879.5 sec
#
# ############################
# ########## Fold 5 ##########
# ############################
# Normalizing...done
# Epoch 1/100
# 2344/2344 - 22s - 9ms/step - loss: 0.0861 - root_mean_squared_error: 0.2935 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0397 - learning_rate: 1.0000e-03
# Epoch 2/100
# 2344/2344 - 18s - 8ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389 - val_loss: 8.9069e-04 - val_root_mean_squared_error: 0.0298 - learning_rate: 1.0000e-03
# Epoch 3/100
# 2344/2344 - 18s - 8ms/step - loss: 0.0012 - root_mean_squared_error: 0.0340 - val_loss: 6.0310e-04 - val_root_mean_squared_error: 0.0246 - learning_rate: 1.0000e-03
# Epoch 4/100
# 2344/2344 - 18s - 8ms/step - loss: 0.0010 - root_mean_squared_error: 0.0323 - val_loss: 5.3578e-04 - val_root_mean_squared_error: 0.0231 - learning_rate: 1.0000e-03
# Epoch 5/100
# 2344/2344 - 17s - 7ms/step - loss: 8.8660e-04 - root_mean_squared_error: 0.0298 - val_loss: 4.9770e-04 - val_root_mean_squared_error: 0.0223 - learning_rate: 1.0000e-03
# Epoch 6/100
# 2344/2344 - 17s - 7ms/step - loss: 8.3419e-04 - root_mean_squared_error: 0.0289 - val_loss: 8.3620e-04 - val_root_mean_squared_error: 0.0289 - learning_rate: 1.0000e-03
# Epoch 7/100
# 2344/2344 - 18s - 8ms/step - loss: 7.5826e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.6490e-04 - val_root_mean_squared_error: 0.0216 - learning_rate: 1.0000e-03
# Epoch 8/100
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2344/2344 - 18s - 8ms/step - loss: 7.3034e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.6259e-04 - val_root_mean_squared_error: 0.0215 - learning_rate: 1.0000e-03
# Epoch 9/100
# 2344/2344 - 18s - 8ms/step - loss: 6.0138e-04 - root_mean_squared_error: 0.0245 - val_loss: 3.6756e-04 - val_root_mean_squared_error: 0.0192 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2344/2344 - 18s - 8ms/step - loss: 5.8662e-04 - root_mean_squared_error: 0.0242 - val_loss: 3.9642e-04 - val_root_mean_squared_error: 0.0199 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2344/2344 - 17s - 7ms/step - loss: 5.8715e-04 - root_mean_squared_error: 0.0242 - val_loss: 4.2884e-04 - val_root_mean_squared_error: 0.0207 - learning_rate: 5.0000e-04
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2344/2344 - 17s - 7ms/step - loss: 5.5404e-04 - root_mean_squared_error: 0.0235 - val_loss: 4.2785e-04 - val_root_mean_squared_error: 0.0207 - learning_rate: 5.0000e-04
# Epoch 13/100
# 2344/2344 - 17s - 7ms/step - loss: 5.1038e-04 - root_mean_squared_error: 0.0226 - val_loss: 3.4582e-04 - val_root_mean_squared_error: 0.0186 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2344/2344 - 20s - 9ms/step - loss: 5.0047e-04 - root_mean_squared_error: 0.0224 - val_loss: 3.3741e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 2.5000e-04
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2344/2344 - 19s - 8ms/step - loss: 4.9866e-04 - root_mean_squared_error: 0.0223 - val_loss: 3.3683e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 2.5000e-04
# Epoch 16/100
# 2344/2344 - 18s - 8ms/step - loss: 4.6804e-04 - root_mean_squared_error: 0.0216 - val_loss: 3.2132e-04 - val_root_mean_squared_error: 0.0179 - learning_rate: 1.2500e-04
# Epoch 17/100
# 2344/2344 - 18s - 8ms/step - loss: 4.6653e-04 - root_mean_squared_error: 0.0216 - val_loss: 3.4072e-04 - val_root_mean_squared_error: 0.0185 - learning_rate: 1.2500e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2344/2344 - 18s - 8ms/step - loss: 4.6298e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.3829e-04 - val_root_mean_squared_error: 0.0184 - learning_rate: 1.2500e-04
# Epoch 19/100
# 2344/2344 - 18s - 8ms/step - loss: 4.4665e-04 - root_mean_squared_error: 0.0211 - val_loss: 3.1372e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 6.2500e-05
# Epoch 20/100
# 2344/2344 - 18s - 8ms/step - loss: 4.4182e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.1228e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 6.2500e-05
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2344/2344 - 18s - 8ms/step - loss: 4.3941e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.1541e-04 - val_root_mean_squared_error: 0.0178 - learning_rate: 6.2500e-05
# Epoch 22/100
# 2344/2344 - 17s - 7ms/step - loss: 4.3770e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.1235e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 3.1250e-05
# Epoch 23/100
# 2344/2344 - 16s - 7ms/step - loss: 4.3452e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1282e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 3.1250e-05
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2344/2344 - 17s - 7ms/step - loss: 4.3344e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1347e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 3.1250e-05
# Epoch 25/100
# 2344/2344 - 16s - 7ms/step - loss: 4.3472e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.1068e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.5625e-05
# Epoch 26/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2800e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1242e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 1.5625e-05
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2344/2344 - 16s - 7ms/step - loss: 4.2731e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1072e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.5625e-05
# Epoch 28/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2687e-04 - root_mean_squared_error: 0.0207 - val_loss: 3.1072e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 7.8125e-06
# Epoch 29/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2609e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1048e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 7.8125e-06
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.2495e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1026e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 7.8125e-06
# Epoch 31/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2487e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1068e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 3.9063e-06
# Epoch 32/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2256e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0982e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 3.9063e-06
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2344/2344 - 18s - 8ms/step - loss: 4.2344e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1019e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 3.9063e-06
# Epoch 34/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2142e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.1012e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.9531e-06
# Epoch 35/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2355e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0986e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.9531e-06
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2344/2344 - 17s - 7ms/step - loss: 4.2094e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.1010e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.9531e-06
# Epoch 37/100
# 2344/2344 - 17s - 7ms/step - loss: 4.1995e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0969e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 38/100
# 2344/2344 - 16s - 7ms/step - loss: 4.2463e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0982e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 39/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2201e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0973e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 40/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2158e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0977e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 41/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2603e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0964e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 42/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2046e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.1018e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 43/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2090e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0990e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 44/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2285e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1019e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 45/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2599e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0968e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 46/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2349e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1053e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 47/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1830e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0947e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 48/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2417e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1304e-04 - val_root_mean_squared_error: 0.0177 - learning_rate: 1.0000e-06
# Epoch 49/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1807e-04 - root_mean_squared_error: 0.0204 - val_loss: 3.0942e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 50/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2279e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1107e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 51/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2316e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0985e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 52/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2413e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1115e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 53/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1966e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0982e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 54/100
# 2344/2344 - 17s - 7ms/step - loss: 4.2497e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1150e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 55/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2218e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.1004e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 56/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2499e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0945e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 57/100
# 2344/2344 - 18s - 8ms/step - loss: 4.1990e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.0966e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 58/100
# 2344/2344 - 19s - 8ms/step - loss: 4.2337e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.1003e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 59/100
# 2344/2344 - 18s - 8ms/step - loss: 4.2525e-04 - root_mean_squared_error: 0.0206 - val_loss: 3.0983e-04 - val_root_mean_squared_error: 0.0176 - learning_rate: 1.0000e-06
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 49.
# 293/293 - 1s - 4ms/step
# 489/489 - 1s - 3ms/step
# Fold 5 RMSE: 0.0618
# Feature engineering & training time: 1043.8 sec
#
# Overall OOF RMSE: 0.0624
#
# Predictions Summary:
# OOF range: 0.50 - 5.88
# Test range: 0.56 - 5.75
# Target range: 0.69 - 5.75

# %%
# import time
# from sklearn.model_selection import KFold
# from sklearn.metrics import mean_squared_error

# FOLDS = 5
# kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)


# test_predictions = np.zeros(len(X_test))
# oof_predictions = np.zeros(len(X)) 

# for fold, (train_idx, valid_idx) in enumerate(kf.split(X, y)):
    
#     print(f"\n{'#'*28}")
#     print(f"{'#'*10} Fold {fold+1} {'#'*10}")
#     print(f"{'#'*28}")

#     # TRAIN
#     X_train = X.loc[train_idx,FEATURES].copy()
#     y_train = np.log1p( y.loc[train_idx,TARGET] )

#     # EXTRA DATA
#     # for k in range(4):
#     #     X_train = pd.concat([X_train,orig[FEATURES]],axis=0)
#     #     y_train = pd.concat([y_train,np.log1p( orig[TARGET] )],axis=0)

#     # VALID
#     X_valid = X.loc[valid_idx,FEATURES].copy()
#     y_valid = np.log1p( y.loc[valid_idx,TARGET] )

#     # TEST
#     X_test_data = X_test[FEATURES].copy()

#     # NORMALIZE FOR NN
#     print("Normalizing...", end='')
#     norm_cols = [c for c in FEATURES if c not in []]
#     means = X_train[norm_cols].mean()
#     stds = X_train[norm_cols].std()
#     stds = stds.replace(0, 1)
#     X_train[norm_cols] = (X_train[norm_cols] - means) / stds
#     X_valid[norm_cols] = (X_valid[norm_cols] - means) / stds
#     X_test_data[norm_cols] = (X_test_data[norm_cols] - means) / stds
#     print("done")
    
#     start = time.time()

#     K.clear_session()
#     model = build_model( X_train.shape[1] )
#     model.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
#                     loss="mse", 
#                     metrics=[tf.keras.metrics.RootMeanSquaredError()],
#                  )
#     model.fit(X_train, y_train, 
#               validation_data = (X_valid, y_valid),
#               callbacks = make_callbacks(),
#               batch_size=256, epochs=EPOCHS, verbose=2)

#     oof_predictions[valid_idx] = model.predict(X_valid,batch_size=512,verbose=2).flatten()
#     test_predictions += model.predict(X_test_data,batch_size=512,verbose=2).flatten()

#     rmse = np.sqrt(mean_squared_error(y_valid, oof_predictions[valid_idx]))
#     print(f"Fold {fold+1} RMSE: {rmse:.4f}")
#     print(f"Feature engineering & training time: {time.time() - start:.1f} sec")

# test_predictions /= FOLDS

# %%
full_rmse = np.sqrt(mean_squared_error(np.log1p(y[TARGET]), oof_predictions))
print(f"Overall CV RMSE: {full_rmse:.5f}")
# np.save(f"oof_v{VER}",oof_predictions)
# Out:
# Overall CV RMSE: 2.63365

# %%
test_predictions
# Out:
# array([3.3510078 , 4.68666677, 4.45688219, ..., 4.30832596, 5.12852554,
#        4.37116652])

# %%
mn = y.Calories.min()
mx = y.Calories.max()
X_test['Calories'] = np.clip( np.expm1( test_predictions ),mn,mx )
test_predictions
# Out:
# array([3.3510078 , 4.68666677, 4.45688219, ..., 4.30832596, 5.12852554,
#        4.37116652])

# %% [markdown]
# ## Submission

# %%
import os 


mn = y.Calories.min()
mx = y.Calories.max()

submission = pd.read_csv('../../dataset/sample_submission.csv')
test_predictions = np.expm1(test_predictions)

i = 1 
while os.path.exists(f"../predictions/submissions/nn_submission_{i}.csv"):
    i+=1

submission["Calories"] = test_predictions

csv_filename = f"../predictions/submissions/nn_submission_{i}.csv"
submission.to_csv(csv_filename, index=False)
print(f"Fichier CSV enregistré : {csv_filename}")

npy_filename = f"../predictions/oof/nn_oof_predictions_{i}.npy"
np.save(npy_filename, oof_predictions)
print(f"Fichier NumPy enregistré : {npy_filename}")
# Out:
# Fichier CSV enregistré : ../predictions/submissions/nn_submission_1.csv
# Fichier NumPy enregistré : ../predictions/oof/nn_oof_predictions_1.npy
